# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanseyy/ELiteTech-intern-task-1/blob/main/diamond.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/archive (4).zip")

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df = pd.read_csv("/content/diamonds [MConverter.eu].txt",delimiter=",")

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df = pd.read_json("/content/export.json")

# %%
df.head()
# Out:
#       carat      cut color clarity  depth  table  price     x     y     z
# 0  1   0.23    Ideal     E     SI2   61.5   55.0  326.0  3.95  3.98  2.43
# 1  2   0.21  Premium     E     SI1   59.8   61.0  326.0  3.89  3.84  2.31
# 2  3   0.23     Good     E     VS1   56.9   65.0  327.0  4.05  4.07  2.31
# 3  4   0.29  Premium     I     VS2   62.4   58.0  334.0  4.20  4.23  2.63
# 4  5   0.31     Good     J     SI2   63.3   58.0  335.0  4.34  4.35  2.75

# %%
df = pd.read_excel("/content/diamonds.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df = pd.read_csv("/content/archive (4).zip")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
2**64  #int64means we can save upto 18446744073709551616 records
# Out:
# 18446744073709551616

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail(2)
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
df.sample(3)
# Out:
#        Unnamed: 0  carat    cut color clarity  depth  table  price     x  \
# 37745       37746   0.31   Fair     D    VVS2   54.2   65.0    997  4.61
# 12028       12029   1.18  Ideal     I     SI1   62.1   56.0   5154  6.79
# 31303       31304   0.32  Ideal     D     VS2   61.3   56.0    758  4.37
#
#           y     z
# 37745  4.58  2.49
# 12028  6.77  4.21
# 31303  4.41  2.69

# %%
df['color']
# Out:
# 0        E
# 1        E
# 2        E
# 3        I
# 4        J
#         ..
# 53935    D
# 53936    D
# 53937    D
# 53938    H
# 53939    D
# Name: color, Length: 53940, dtype: object

# %%
df['price']
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
df.loc[:9,['color','price']]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327
# 3     I    334
# 4     J    335
# 5     J    336
# 6     I    336
# 7     H    337
# 8     E    337
# 9     H    338

# %%
df.iloc[:2,[0,3]]
# Out:
#    Unnamed: 0 color
# 0           1     E
# 1           2     E

# %%
df['table'].value_counts()
# Out:
# table
# 56.0    9881
# 57.0    9724
# 58.0    8369
# 59.0    6572
# 55.0    6268
#         ...
# 51.6       1
# 63.5       1
# 43.0       1
# 62.4       1
# 61.6       1
# Name: count, Length: 127, dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
df['depth'].describe()
# Out:
# count    53940.000000
# mean        61.749405
# std          1.432621
# min         43.000000
# 25%         61.000000
# 50%         61.800000
# 75%         62.500000
# max         79.000000
# Name: depth, dtype: float64

# %%
df.describe(include='object')
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
df.nunique()
# Out:
# Unnamed: 0    53940
# carat           273
# cut               5
# color             7
# clarity           8
# depth           184
# table           127
# price         11602
# x               554
# y               552
# z               375
# dtype: int64

# %%
df['price'].unique()
# Out:
# array([ 326,  327,  334, ..., 2753, 2755, 2756])

# %%
##Descrptive statistics

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df['color'].count()
# Out:
# 53940

# %%
df['depth'].max()
# Out:
# 79.0

# %%
df['depth'].min()
# Out:
# 43.0

# %%
df['depth'].median()
# Out:
# 61.8

# %%
df['depth'].mode()
# Out:
# 0    62.0
# Name: depth, dtype: float64

# %%
df['depth'].std()
# Out:
# 1.4326213188337733

# %%
df['depth'].var()
# Out:
# 2.05240384317702

# %%
df['depth'].quantile(0)#0 min `1 max
# Out:
# 43.0

# %%
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
df['x']
# Out:
# 0        3.95
# 1        3.89
# 2        4.05
# 3        4.20
# 4        4.34
#          ...
# 53935    5.75
# 53936    5.69
# 53937    5.66
# 53938    6.15
# 53939    5.83
# Name: x, Length: 53940, dtype: float64

# %%
df1 = df.select_dtypes(exclude='object')

# %%
df1
# Out:
#        Unnamed: 0  carat  depth  table  price     x     y     z
# 0               1   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1               2   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2               3   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3               4   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4               5   0.31   63.3   58.0    335  4.34  4.35  2.75
# ...           ...    ...    ...    ...    ...   ...   ...   ...
# 53935       53936   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936       53937   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937       53938   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938       53939   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939       53940   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %%
filter_data = df[df['price']<=400]

# %%
filter_data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 50616       50617   0.25       Good     D     VS1   57.6   60.0    399  4.15
# 50617       50618   0.31      Ideal     J     VS2   61.8   54.1    400  4.35
# 50618       50619   0.31      Ideal     J     VS2   62.1   53.6    400  4.36
# 50619       50620   0.23  Very Good     E     VS2   62.4   60.0    400  3.90
# 50620       50621   0.23    Premium     E     VS1   61.8   60.0    400  3.91
#
#           y     z
# 0      3.98  2.43
# ...

# %%
add = lambda x,y : x+y

# %%
add(100,200)
# Out:
# 300

# %%
import seaborn as sns

# %%
diamonds = sns.load_dataset('diamonds')

# %%
print(diamonds.head())
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.set(style="whitegrid")

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
sns.histplot(diamonds['price'], kde=True, color='blue')
plt.title('Distribution of Diamond Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Scatter Plot: Carat vs Price
plt.figure(figsize=(8, 6))
sns.scatterplot(x='carat', y='price', data=diamonds, hue='cut', palette='viridis', alpha=0.7)
plt.title('Carat vs Price')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.legend(title='Cut')
plt.show()

# %%
# 3. Box Plot: Price by Cut
diamonds.boxplot(column='price', by='cut', grid=False, color=dict(boxes='blue', whiskers='black', medians='red'))
plt.title('Price by Cut')
plt.suptitle('')  # Remove default title
plt.xlabel('Cut')
plt.ylabel('Price')
plt.show()

# %%
# 4. Correlation Heatmap
corr = diamonds.corr(numeric_only=True)  # Calculate correlation only for numeric columns
plt.matshow(corr, cmap='coolwarm')
plt.colorbar()
plt.title('Correlation Matrix', pad=20)
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()
